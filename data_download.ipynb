# %% [markdown]
# # Connection with SYNAPSE for BraTS dataset

# %%
from synapseclient import Synapse
import synapseutils

# %%
syn = Synapse(configPath="./.synapseConfig")
syn.login()
# Out:
# Welcome, jose_berlin!

# %%
project_id = "syn23525954"
download_location = "./brats2020_data/"

# %%
dl_list_file_entities = syn.get_download_list(downloadLocation=download_location) # get list of files to download
# Out:
# /download/list/manifest/async:   0%|                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       | 0.00/1.00 [00:00<?, ?it/s
# ...

# %% [markdown]
# # Extract Zip Files

# %%
import zipfile, os

location = "./brats2020_data/"

for file in os.listdir(location):
    if file.endswith(".zip"):
        file_path = os.path.join(location, file)
        with zipfile.ZipFile(file_path, 'r') as zip_ref:
            zip_ref.extractall(location)
        print(f"Extracted: {file_path}")
# Out:
# Extracted: ./brats2020_data/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData.zip
# Extracted: ./brats2020_data/ASNR-MICCAI-BraTS2023-GLI-Challenge-ValidationData.zip

# %%
len(os.listdir("./brats2020_data/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData"))
# Out:
# 1251

# %%
len(os.listdir("./brats2020_data/ASNR-MICCAI-BraTS2023-GLI-Challenge-ValidationData"))
# Out:
# 219
